# %%
import numpy as np
import sys

# %%
arr=np.array([23,45,18,7])

# %%
arr
# Out:
# array([23, 45, 18,  7])

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
arr.astype("float32")
# Out:
# array([23., 45., 18.,  7.], dtype=float32)

# %%
arr.astype("bool")
# Out:
# array([ True,  True,  True,  True])

# %%
arr.astype("complex64")
# Out:
# array([23.+0.j, 45.+0.j, 18.+0.j,  7.+0.j], dtype=complex64)

# %%
arr1=np.array([1,2,3],dtype="int64") # in int64 3*8byte=24
arr2=np.array([1,2,3],dtype="int32") #in int32 3*4byte=12

# %%
print(arr1.nbytes)
# Out:
# 24

# %%
print(arr2.nbytes)
# Out:
# 12

# %%
import pandas as pd

# %%
# Series datastructure(1D array with labels)in pandas it is similar to dictionary in python 
#it automatically gives labels (index) to data
s1=pd.Series([10,21,33,87,54])

# %%
s1
# Out:
# 0    10
# 1    21
# 2    33
# 3    87
# 4    54
# dtype: int64

# %%
# for giveing our own index
s2=pd.Series([77,81,73,87,84],index=["suraj","aditya","Om","swami","kunal"])

# %%
s2
# Out:
# suraj     77
# aditya    81
# Om        73
# swami     87
# kunal     84
# dtype: int64

# %%
#Dataframe datastructure (2D array with label ) in pandas its like Excel data
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

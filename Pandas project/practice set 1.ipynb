# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Score': [85, 90, 95, 80, 75]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age Gender  Score
# 0    Alice   25      F     85
# 1      Bob   30      M     90
# 2  Charlie   35      M     95
# 3    David   40      M     80
# 4      Eva   45      F     75

# %%
# 1st problem printing first 3 rows
df.loc[0:2]
# Out:
#       Name  Age Gender  Score
# 0    Alice   25      F     85
# 1      Bob   30      M     90
# 2  Charlie   35      M     95
# 3    David   40      M     80

# %%
# 2nd problem check shape,column and datatype
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Score'], dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 3rd problem get summary of dataframe
df.describe()
# Out:
#              Age      Score
# count   5.000000   5.000000
# mean   35.000000  85.000000
# std     7.905694   7.905694
# min    25.000000  75.000000
# 25%    30.000000  80.000000
# 50%    35.000000  85.000000
# 75%    40.000000  90.000000
# max    45.000000  95.000000

# %%
#4th problem filter row 
#method 1
df[df["Score"]>70]
# Out:
#       Name  Age Gender  Score
# 0    Alice   25      F     85
# 1      Bob   30      M     90
# 2  Charlie   35      M     95
# 3    David   40      M     80
# 4      Eva   45      F     75

# %%
#method 2
df.query("Score >70")
# Out:
#       Name  Age Gender  Score
# 0    Alice   25      F     85
# 1      Bob   30      M     90
# 2  Charlie   35      M     95
# 3    David   40      M     80
# 4      Eva   45      F     75

# %%
# 5th problem Adding new column 
df["Pass"]=df["Score"].apply(lambda x: "True" if x>=80 else "False")

# %%
df
# Out:
#       Name  Age Gender  Score   Pass
# 0    Alice   25      F     85   True
# 1      Bob   30      M     90   True
# 2  Charlie   35      M     95   True
# 3    David   40      M     80   True
# 4      Eva   45      F     75  False

# %%
#6th problem change Score column name to Marks
df.rename(columns={"Score":"Marks"})
# Out:
#       Name  Age Gender  Marks   Pass
# 0    Alice   25      F     85   True
# 1      Bob   30      M     90   True
# 2  Charlie   35      M     95   True
# 3    David   40      M     80   True
# 4      Eva   45      F     75  False

# %%
#7th problem drop column
df.drop(columns=["Gender"],inplace=True)

# %%
df
# Out:
#       Name  Age  Score   Pass
# 0    Alice   25     85   True
# 1      Bob   30     90   True
# 2  Charlie   35     95   True
# 3    David   40     80   True
# 4      Eva   45     75  False

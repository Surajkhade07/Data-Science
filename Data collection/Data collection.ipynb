# %%
import requests

# %%
a = requests.get("https://books.toscrape.com/")

# %%
with open (f"Htmls/first.html","w") as f:
    f.write(a.text)

# %%
a.status_code
# Out:
# 200

# %%
a.headers
# Out:
# {'Date': 'Sat, 12 Jul 2025 05:14:26 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Last-Modified': 'Wed, 08 Feb 2023 21:02:32 GMT', 'ETag': 'W/"63e40de8-c85e"', 'Strict-Transport-Security': 'max-age=0; includeSubDomains; preload', 'Content-Encoding': 'br'}

# %%
# for downloding all pages 
for i in range (1,31):
    a=requests.get(f"https://books.toscrape.com/catalogue/page-{i}.html")
    with open (f"Htmls/page{i}.html","w",encoding="utf-8") as f:
        f.write(a.text)
        
print("All pages Downlode successfuly")
# Out:
# All pages Downlode successfuly

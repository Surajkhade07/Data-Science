# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style="darkgrid")
x=np.array([x for x in range (1,10)])
y=np.cos(x) # trignometric function

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >
